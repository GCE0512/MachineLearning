# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(rc={'figure.figsize': (6, 6)})

# %% [markdown]
# ### 调色板
# * 颜色很重要
#
# * color_palette()能传入任何Matplotlib所支持的颜色
#
# * color_palette()不写参数则默认颜色
#
# * set_palette()设置所有图的颜色

# %% [markdown]
# ### 分类色板

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %% [markdown]
# # 6个默认颜色循环主题:deep, nuted, pastel, bright, dark, colorblind

# %% [markdown]
# ### 圆形画板
# 当你有六个以上的分类要分区时，最简单的方法就是在一个圆形的颜色空间中画出均匀间隔的颜色（这样的色调会保持亮度和饱和度不变）。这是大多数的当他们需要使用比当前默认颜色循环中设置的颜色更多时的默认方案。
#
# 最常用的方法是使用his的颜色空间，这是RGB值得一个简单转换。

# %%
sns.palplot(sns.color_palette('hls', 10)) # 后面那个值表示生成颜色的个数

# %%
data = np.random.normal(size=(20, 8)) + np.arange(8) / 2
sns.boxplot(data=data, palette=sns.color_palette('hls', 8))

# %% [markdown]
# ### his_palette()函数来控制颜色的亮度和饱和
# * l-亮度 lightness
#
# * s-饱和 saturation

# %%
sns.palplot(sns.hls_palette(8, l=0.8, s=0.8)) # 调亮度和饱和度

# %%
sns.palplot(sns.color_palette('Paired', 10)) # 调色板是一对一对分布

# %% [markdown]
# ### 使用xkcd颜色来命名颜色
# xkcd包含了一套众包努力的针对随机RGB色的命名。产生了954个可以随时通过xdcd_rgb字典中调用的命名颜色。

# %%
plt.plot([0, 1], [0, 1], sns.xkcd_rgb['pale red'], lw=3)
plt.plot([0, 1], [0, 2], sns.xkcd_rgb['medium green'], lw=3)
plt.plot([0, 1], [0, 3], sns.xkcd_rgb['denim blue'], lw=3)

# %%
colors = ['windows blue', 'amber', 'greyish', 'faded green', 'dusty purple']
sns.palplot(sns.xkcd_palette(colors))

# %% [markdown]
# ### 连续色板
# 色彩随数据变换，比如数据越来越重要则颜色越来越深

# %%
sns.palplot(sns.color_palette('Reds'))

# %% [markdown]
# 如果想要翻转渐变，可以在面板名称中添加一个 _r 后缀

# %%
sns.palplot(sns.color_palette('BuGn_r', 10))

# %% [markdown]
# ### cubehelix_palette()调色板
# 色调线性变换

# %%
sns.palplot(sns.color_palette('cubehelix', 8))

# %%
sns.palplot(sns.cubehelix_palette(8, start=0.5, rot=-0.75))

# %%
sns.palplot(sns.cubehelix_palette(8, start=0.75, rot=-0.150))

# %% [markdown]
# ### light_palette()和dark_palette()调用定制连续调色板

# %%
sns.palplot(sns.light_palette('green')) # 指定深浅

# %%
sns.palplot(sns.dark_palette('purple'))

# %%
sns.palplot(sns.light_palette('navy', reverse=True)) # 翻转，由深到浅

# %%
x, y = np.random.multivariate_normal([0, 0], [[1, -0.5], [-.5, 1]], size=300).T
pal = sns.dark_palette('green', as_cmap=True)
sns.kdeplot(x, y, cmap=pal);

# %%
sns.palplot(sns.light_palette((210, 90, 60), input='husl'))
